# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyarrow

# Two most comprehensive datasets
combined_data = pd.read_csv('data/phishing_email.csv')
CEAS_data = pd.read_csv('data/CEAS_08.csv')

# %%
# All data combined, will take some formatting to process correctly
combined_data.head()
# Out:
#                                        text_combined  label
# 0  hpl nom may 25 2001 see attached file hplno 52...      0
# 1  nom actual vols 24 th forwarded sabrae zajac h...      0
# 2  enron actuals march 30 april 1 201 estimated a...      0
# 3  hpl nom may 30 2001 see attached file hplno 53...      0
# 4  hpl nom june 1 2001 see attached file hplno 60...      0

# %%
# Biggest single dataset with all features
CEAS_data.head()
# Out:
#                                               sender  \
# 0                   Young Esposito <Young@iworld.de>
# 1                       Mok <ipline's1983@icable.ph>
# 2  Daily Top 10 <Karmandeep-opengevl@universalnet...
# 3                 Michael Parker <ivqrnai@pobox.com>
# 4  Gretchen Suggs <externalsep1@loanofficertool.com>
#
#                                          receiver  \
# 0                     user4@gvc.ceas-challenge.cc
# 1                   user2.2@gvc.ceas-challenge.cc
# 2                   user2.9@gvc.ceas-challenge.cc
# 3  SpamAssassin Dev <xrh@spamassassin.apache.org>
# 4                   user2.2@gvc.ceas-challenge.cc
#
#                               date  \
# 0  Tue, 05 Aug 2008 16:31:02 -0700
# 1  Tue, 05 Aug 2008 18:31:03 -0500
# 2  Tue, 05 Aug 2008 20:28:00 -1200
# 3  Tue, 05 Aug 2008 17:31:20 -0600
# 4  Tue, 05 Aug 2008 19:31:21 -0400
#
#                                              subject  \
# 0                          Never agree to be a loser
# ...

# %%
print('Before: ')
print(len(combined_data), ' entries in combined_data')
print(len(CEAS_data), ' entries in CEAS_data')

combined_data_clean = combined_data.dropna()
CEAS_data_clean = CEAS_data.dropna()

print('After: ')
print(len(combined_data_clean), 'entries in combined_data')
print(len(CEAS_data_clean), 'entries in CEAS_data')
# Out:
# Before:
# 82486  entries in combined_data
# 39154  entries in CEAS_data
# After:
# 82486 entries in combined_data
# 38669 entries in CEAS_data

# %%
from datasets import Dataset

combined_dataset = Dataset.from_pandas(combined_data_clean)
CEAS_dataset = Dataset.from_pandas(CEAS_data_clean)
